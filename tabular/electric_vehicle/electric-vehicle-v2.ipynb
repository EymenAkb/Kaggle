# %% [markdown]
# <a href="https://www.kaggle.com/code/eymenakb/electric-vehicle-v2?scriptVersionId=347442177" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Welcome
# ### This is a basic script using xgboost and optuna for Predicting Electric Vehicle Purchases
#
# competition: [comptetition](https://www.kaggle.com/competitions/playground-series-s6e9)
# kaggle: [kaggle](https://www.kaggle.com/eymenakb)
# github: [github](https://github.com/EymenAkb)

# %% [markdown]
# ## Installing the dependencies
#
# `optuna-integration`: Installed for `PruningCallback` usage, for more info check out [optuna-integration](https://optuna.readthedocs.io/en/v2.0.0/reference/integration) and [PruningCallBack](https://optuna.readthedocs.io/en/v2.0.0/reference/generated/optuna.integration.XGBoostPruningCallback)
#
# `category_encoders`: Installed for `CatBoostEncoder` usage, for further info check out [category_encoders](https://contrib.scikit-learn.org/category_encoders/) and [CatBoostEncoder](https://contrib.scikit-learn.org/category_encoders/catboost)

# %%
# !pip install optuna optuna-integration scikit-learn
# !pip install category_encoders
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (4.9.0)
# Collecting optuna-integration
#   Downloading optuna_integration-4.9.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.18.4)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (26.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.49)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.11)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.4.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna_integration-4.9.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: optuna-integration
# Successfully installed optuna-integration-4.9.0
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.12/dist-packages (2.9.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.3.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.16.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (0.14.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2026.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.9.0->category_encoders) (26.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/competitions/playground-series-s6e9/sample_submission.csv
# /kaggle/input/competitions/playground-series-s6e9/train.csv
# /kaggle/input/competitions/playground-series-s6e9/test.csv

# %% [markdown]
# ## Importing the neccesarry libraries
#
# #### Descriptions and Libraries:
#
# xgboost: A library for gradient boosted machine Learning.
#
# optuna: Machine Learning optimization library.
#
# matplotlib.pyplot: Visualization and plotting library.
# seaborn: Visualization and plotting library.
#
# math: native python mathematical work library.
#
# sci-kit_learn (sklearn): Optimization, pipelines, composing, preprocessing, folding and every preprocess step handler for ML.
#
# category_encoders: Encoding the categorical values (for long and seep values).

# %%
import xgboost as xgb
from xgboost import XGBClassifier

import optuna

import matplotlib.pyplot as plt
import seaborn as sns

import math

from category_encoders.cat_boost import CatBoostEncoder

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# #### Plot settings, finding the available styles and using one

# %%
#plt.style.available # useful for checking the available plt styles.
plt.style.use("seaborn-v0_8")

# %% [markdown]
# ## Mini utility methods
#
# ### Descriptions:
#
# num_cols: used for selecting numerical_columns, DRY (Don't repeat yourself) code.
# cat_cols: used for selecting categorical_columns, DRY (Don't repeat yourself) code.
#
# `feature_all_charge_stations`: feature code, new column that sums up charging stations near home and nearh work.
#
# `feature_km_by_car`: feature code, new column for calculating the km usage per car.
#
# `feature_annual_income_digits`: feature code, new column for each digit of the `Annual_Income_USD`.
#
# `feature_daily_commute_km_digits`: feature code, new column for each digit of the `Daily_Commute_km`.

# %%
def num_cols(data) -> list:
    return data.select_dtypes(include=np.number).columns.tolist()

def cat_cols(data) -> list:
    return data.select_dtypes(exclude=np.number).columns.tolist()

def feature_all_charge_stations(data, return_columns:bool=False, copy:bool=False) -> pd.DataFrame | tuple[pd.DataFrame, list, list]:
    if copy:
        data = data.copy(True)
    data["all_charge_stations"] = data["Charging_Stations_Near_Home"] + data["Charging_Stations_Near_Work"]
    if return_columns:
        numerical_columns = num_cols(data)
        categorical_columns = cat_cols(data)
        return data, numerical_columns, categorical_columns
    return data

def feature_km_by_car(data, return_columns:bool=False, copy:bool=False) -> pd.DataFrame | tuple[pd.DataFrame, list, list]:
    if copy:
        data = data.copy(True)
    data["km_by_car"] = data["Daily_Commute_km"] / data["Number_of_Cars_Owned"].replace(0, np.nan)
    if return_columns:
        numerical_columns = num_cols(data)
        categorical_columns = cat_cols(data)
        return data, numerical_columns, categorical_columns
    return data

def feature_annual_income_digits(data, return_columns:bool=False, copy:bool=False) -> pd.DataFrame | tuple[pd.DataFrame, list, list]:
    if copy:
        data = data.copy()
        
    income = data['Annual_Income_USD'].fillna(0).astype(int)
    data['digit_100k'] = ((income // 100_000) % 10).astype(str)
    data['digit_10k']  = ((income // 10_000) % 10).astype(str)
    data['digit_1k']   = ((income // 1_000) % 10).astype(str)
    data['digit_100s'] = ((income // 100) % 10).astype(str)

    data[['digit_100k', 'digit_10k', 'digit_1k', 'digit_100s']] = data[['digit_100k', 'digit_10k', 'digit_1k', 'digit_100s']].astype('category')

    if return_columns:
        numerical_columns = num_cols(data)
        categorical_columns = cat_cols(data)
        return data, numerical_columns, categorical_columns
    return data

def feature_daily_commute_km_digits(data, return_columns:bool=False, copy:bool=False) -> pd.DataFrame | tuple[pd.DataFrame, list, list]:
    if copy:
        data = data.copy()

    daily_com = data['Daily_Commute_km'].fillna(0).astype(int)

    data["digit_100"] = ((daily_com // 100) % 10).astype(str)
    data["digit_10"] = ((daily_com // 10) % 10).astype(str)
    data["digit_1"] = ((daily_com // 1) % 10).astype(str)
    
    if return_columns:
        numerical_columns = num_cols(data)
        categorical_columns = cat_cols(data)
        return data, numerical_columns, categorical_columns
    return data

# %% [markdown]
# # Loading the data
# Handling feature engineering and other variables, removing the target from columns and calculating unique count of cateogrical columns (used for finding which encoding method is useful)

# %%
train_df = pd.read_csv("/kaggle/input/competitions/playground-series-s6e9/train.csv", index_col=0)
test_df = pd.read_csv("/kaggle/input/competitions/playground-series-s6e9/test.csv", index_col=0)

feature_all_charge_stations(train_df)
feature_km_by_car(train_df)
feature_all_charge_stations(test_df)
feature_km_by_car(test_df)
feature_annual_income_digits(train_df)
feature_annual_income_digits(test_df)
feature_daily_commute_km_digits(train_df)
feature_daily_commute_km_digits(test_df)

numerical_columns = num_cols(train_df)
categorical_columns = cat_cols(train_df)
target = "Will_Buy_EV"

if target in numerical_columns:
    numerical_columns.remove(target)
    
if target in categorical_columns:
    categorical_columns.remove(target)
    
total_cat = 0
total_cat = train_df[categorical_columns].nunique().sum()

print(f"Total Categorical unique values:\n{total_cat - 2}\n")

train_df.info()
# Out:
# Total Categorical unique values:
# 68
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 668665 entries, 0 to 668664
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Age                          668665 non-null  int64
#  1   Annual_Income_USD            668665 non-null  float64
#  2   Daily_Commute_km             668665 non-null  float64
#  3   Number_of_Cars_Owned         668665 non-null  int64
#  4   Charging_Stations_Near_Home  668665 non-null  int64
#  5   Charging_Stations_Near_Work  668665 non-null  int64
#  6   Environmental_Concern_Level  668665 non-null  float64
#  7   Gender                       668665 non-null  object
#  8   City_Type                    668665 non-null  object
#  9   Current_Car_Type             668665 non-null  object
#  10  Home_Charging_Possible       668665 non-null  object
#  11  Subsidy_Available            668665 non-null  object
#  12  Range_Anxiety_Level          668665 non-null  object
#  13  Will_Buy_EV                  668665 non-null  object
#  14  all_charge_stations          668665 non-null  int64
#  15  km_by_car                    668665 non-null  float64
#  16  digit_100k                   668665 non-null  category
#  17  digit_10k                    668665 non-null  category
#  18  digit_1k                     668665 non-null  category
#  19  digit_100s                   668665 non-null  category
#  20  digit_100                    668665 non-null  object
#  21  digit_10                     668665 non-null  object
#  22  digit_1                      668665 non-null  object
# dtypes: category(4), float64(4), int64(5), object(10)
# memory usage: 104.6+ MB

# %% [markdown]
# #### Based off of the skedewness we are going to use `CatBoostEncoder`

# %% [markdown]
# ## Plotting the data
#
# Plotting the categorical_columns using barplot.
# Plotting the numerical_columns using histplot, checking the correlation between numerical values using heatmap.

# %%
row_num = math.ceil((len(numerical_columns) + len(categorical_columns) + 1) / 2)
fig, ax = plt.subplots(nrows=row_num, ncols=2, figsize=(10, row_num * 4), squeeze=False)
axes_flat = ax.ravel()

for i, column in enumerate(categorical_columns):
    counts = train_df[column].value_counts()
    sns.barplot(x=counts.index, y=counts.values, ax=axes_flat[i])

for j, column in enumerate(numerical_columns):
    index_for_ax = len(categorical_columns) + j
    sns.histplot(train_df[column], ax=axes_flat[index_for_ax])

sns.heatmap(train_df[numerical_columns].corr(),annot=True, fmt=".1f")

plt.show()

# %% [markdown]
# # Preprocessing
#
# Setting up the preprocessor.
#
# for `numerical_columns`: passthrough is used, optimal strategy for treemethods. Normalization and scaling may or may not be used instead.
#
# for `categorical_columns`: `CatBoostEncoder` is used, optimal for skewed and complex categorical values.

# %%
preprocessor = ColumnTransformer(transformers=[
    ("num", "passthrough", numerical_columns),
    ("cat", CatBoostEncoder(), categorical_columns)
])

le = LabelEncoder()
x = train_df[numerical_columns + categorical_columns]
y = le.fit_transform(train_df[target])

x_transformed = preprocessor.fit_transform(x, y)

dtrain = xgb.DMatrix(x_transformed, label=y, missing=np.nan)

# %% [markdown]
# ## Optimization / Optuna Trial
#
# ### Setting up a function (objective) to find optimal values
#
# Using `StratifiedKFold` for cross validation. For further info [StratifiedKFold](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedKFold)
#
# Using `PruningCallback` for callbacks. For further info [PruningCallback](https://optuna.readthedocs.io/en/v2.0.0/reference/generated/optuna.integration.XGBoostPruningCallback)

# %%
def objective(trial):
    params = {
        "objective": "binary:logistic",
        "device": "cuda",
        "eval_metric": "logloss",
        "tree_method": "hist",
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.3),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "subsample": trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 15),
        'gamma': trial.suggest_float('gamma', 1e-8, 1.0, log=True),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'max_delta_step': trial.suggest_int('max_delta_step', 0, 10)
    }

    skf = StratifiedKFold(shuffle=True)
    pruning_callback = (optuna.integration.XGBoostPruningCallback(trial, "test-logloss"))
    folds = list(skf.split(x_transformed, y))

    try:
        cv = xgb.cv(params=params, dtrain=dtrain, num_boost_round=1500, folds=folds,
            early_stopping_rounds=50, callbacks=[pruning_callback], verbose_eval=False)

        metric_col = 'test-logloss-mean'

        best_iteration = cv[metric_col].idxmin()

        optimal_n_estimators = (best_iteration + 1)

        trial.set_user_attr("optimal_n_estimators",optimal_n_estimators)

        return cv.loc[best_iteration, metric_col]

    except optuna.exceptions.TrialPruned:
        raise

# %% [markdown]
# ### Creating the study
#
# starting the optimization

# %%
study = optuna.create_study(direction='minimize',sampler=optuna.samplers.TPESampler(multivariate=True, n_startup_trials=10),
                           pruner=optuna.pruners.MedianPruner(n_warmup_steps=5))

study.optimize(objective, n_trials=80)
# Out:
# /tmp/ipykernel_23/1543026696.py:1: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   study = optuna.create_study(direction='minimize',sampler=optuna.samplers.TPESampler(multivariate=True, n_startup_trials=10),
# [I 2026-09-05 09:31:26,380] A new study created in memory with name: no-name-c5122d1f-79c2-4017-8adf-7c2306f7db74
# /usr/lib/python3.12/importlib/__init__.py:90: FutureWarning: `optuna.integration.xgboost` has been deprecated in v4.9.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v4.9.0. Use `optuna_integration.xgboost` instead.
#   return _bootstrap._gcd_import(name[level:], package, level)
# [I 2026-09-05 09:31:52,640] Trial 0 finished with value: 0.22660269671405414 and parameters: {'learning_rate': 0.02197068882303443, 'max_depth': 3, 'subsample': 0.8860647194316036, 'colsample_bytree': 0.9703287673184293, 'min_child_weight': 8, 'gamma': 0.04951209342041917, 'reg_alpha': 3.3953086267292485, 'reg_lambda': 0.002550653967297111, 'max_delta_step': 0}. Best is trial 0 with value: 0.22660269671405414.
# [I 2026-09-05 09:31:58,845] Trial 1 finished with value: 0.22698947303184078 and parameters: {'learning_rate': 0.22283365193673532, 'max_depth': 9, 'subsample': 0.6640525256053595, 'colsample_bytree': 0.7272585254380823, 'min_child_weight': 3, 'gamma': 0.0518390746146941, 'reg_alpha': 6.087379135034844, 'reg_lambda': 5.150532994619992e-08, 'max_delta_step': 10}. Best is trial 0 with value: 0.22660269671405414.
# [I 2026-09-05 09:32:08,073] Trial 2 finished with value: 0.22599130596819114 and parameters: {'learning_rate': 0.10104014120285158, 'max_depth': 5, 'subsample': 0.579568999352094, 'colsample_bytree': 0.9791092953739491, 'min_child_weight': 6, 'gamma': 1.0808348953714984e-05, 'reg_alpha': 0.007977172351954848, 'reg_lambda': 0.0030297726079801792, 'max_delta_step': 2}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:32:17,259] Trial 3 finished with value: 0.22888412616519127 and parameters: {'learning_rate': 0.18008918356366238, 'max_depth': 12, 'subsample': 0.7700667269190562, 'colsample_bytree': 0.8378423662462808, 'min_child_weight': 7, 'gamma': 2.8943650646944934e-08, 'reg_alpha': 0.127637231035074, 'reg_lambda': 1.4536550372607284e-06, 'max_delta_step': 10}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:32:24,581] Trial 4 finished with value: 0.22654141594823957 and parameters: {'learning_rate': 0.1557587738257152, 'max_depth': 5, 'subsample': 0.5157720355581186, 'colsample_bytree': 0.735653156668403, 'min_child_weight': 10, 'gamma': 3.5067603328462157e-06, 'reg_alpha': 9.265315752612104e-07, 'reg_lambda': 0.7618041682997309, 'max_delta_step': 5}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:32:26,243] Trial 5 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:32:28,149] Trial 6 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:32:30,374] Trial 7 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:32:32,110] Trial 8 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:32:33,830] Trial 9 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:32:35,710] Trial 10 pruned. Trial was pruned at iteration 21.
# [I 2026-09-05 09:32:41,180] Trial 11 finished with value: 0.22649763421895847 and parameters: {'learning_rate': 0.23667990006689216, 'max_depth': 4, 'subsample': 0.5999370445749054, 'colsample_bytree': 0.8934105076943978, 'min_child_weight': 11, 'gamma': 2.0229844200305827e-05, 'reg_alpha': 1.0382019924310452e-07, 'reg_lambda': 0.0011651218101455822, 'max_delta_step': 6}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:32:43,059] Trial 12 pruned. Trial was pruned at iteration 17.
# [I 2026-09-05 09:32:48,330] Trial 13 pruned. Trial was pruned at iteration 105.
# [I 2026-09-05 09:32:49,706] Trial 14 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:32:54,114] Trial 15 pruned. Trial was pruned at iteration 124.
# [I 2026-09-05 09:32:58,612] Trial 16 pruned. Trial was pruned at iteration 124.
# [I 2026-09-05 09:33:00,545] Trial 17 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:01,722] Trial 18 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:03,301] Trial 19 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:05,247] Trial 20 pruned. Trial was pruned at iteration 21.
# [I 2026-09-05 09:33:09,775] Trial 21 pruned. Trial was pruned at iteration 98.
# [I 2026-09-05 09:33:10,904] Trial 22 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:12,480] Trial 23 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:14,199] Trial 24 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:16,075] Trial 25 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:17,357] Trial 26 pruned. Trial was pruned at iteration 20.
# [I 2026-09-05 09:33:18,863] Trial 27 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:24,420] Trial 28 pruned. Trial was pruned at iteration 98.
# [I 2026-09-05 09:33:26,295] Trial 29 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:27,399] Trial 30 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:28,715] Trial 31 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:30,401] Trial 32 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:32,338] Trial 33 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:33,286] Trial 34 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:35,141] Trial 35 pruned. Trial was pruned at iteration 30.
# [I 2026-09-05 09:33:36,782] Trial 36 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:38,692] Trial 37 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:39,720] Trial 38 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:41,295] Trial 39 pruned. Trial was pruned at iteration 30.
# [I 2026-09-05 09:33:42,896] Trial 40 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:45,137] Trial 41 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:33:48,881] Trial 42 pruned. Trial was pruned at iteration 82.
# [I 2026-09-05 09:33:53,396] Trial 43 pruned. Trial was pruned at iteration 61.
# [I 2026-09-05 09:33:55,404] Trial 44 pruned. Trial was pruned at iteration 12.
# [I 2026-09-05 09:33:57,338] Trial 45 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:34:04,285] Trial 46 pruned. Trial was pruned at iteration 71.
# [I 2026-09-05 09:34:08,607] Trial 47 pruned. Trial was pruned at iteration 139.
# [I 2026-09-05 09:34:10,236] Trial 48 pruned. Trial was pruned at iteration 10.
# [I 2026-09-05 09:34:15,113] Trial 49 finished with value: 0.22743217170580277 and parameters: {'learning_rate': 0.2752119583310961, 'max_depth': 7, 'subsample': 0.6917042170701342, 'colsample_bytree': 0.9124415065106306, 'min_child_weight': 7, 'gamma': 2.368007827758517e-07, 'reg_alpha': 1.3021516841474059e-05, 'reg_lambda': 0.001235803569196808, 'max_delta_step': 7}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:34:16,268] Trial 50 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:34:20,008] Trial 51 finished with value: 0.22738702485548937 and parameters: {'learning_rate': 0.2873220836585796, 'max_depth': 6, 'subsample': 0.5819425650282709, 'colsample_bytree': 0.7627476407521567, 'min_child_weight': 4, 'gamma': 1.3030433210782596e-07, 'reg_alpha': 1.464111925552551e-05, 'reg_lambda': 1.9804428486956405e-05, 'max_delta_step': 7}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:34:21,260] Trial 52 pruned. Trial was pruned at iteration 9.
# [I 2026-09-05 09:34:22,932] Trial 53 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:34:27,944] Trial 54 finished with value: 0.2275250498685998 and parameters: {'learning_rate': 0.2620085380152796, 'max_depth': 7, 'subsample': 0.6359782730121462, 'colsample_bytree': 0.8470266134906156, 'min_child_weight': 5, 'gamma': 2.03586661189272e-07, 'reg_alpha': 9.728510964323847e-06, 'reg_lambda': 2.3697523487797368e-07, 'max_delta_step': 7}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:34:29,432] Trial 55 pruned. Trial was pruned at iteration 15.
# [I 2026-09-05 09:34:30,676] Trial 56 pruned. Trial was pruned at iteration 16.
# [I 2026-09-05 09:34:32,321] Trial 57 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:34:34,589] Trial 58 pruned. Trial was pruned at iteration 17.
# [I 2026-09-05 09:34:36,279] Trial 59 pruned. Trial was pruned at iteration 15.
# [I 2026-09-05 09:34:39,892] Trial 60 pruned. Trial was pruned at iteration 115.
# [I 2026-09-05 09:34:44,365] Trial 61 pruned. Trial was pruned at iteration 129.
# [I 2026-09-05 09:34:46,299] Trial 62 pruned. Trial was pruned at iteration 11.
# [I 2026-09-05 09:34:52,080] Trial 63 pruned. Trial was pruned at iteration 113.
# [I 2026-09-05 09:34:56,216] Trial 64 finished with value: 0.2271104430279621 and parameters: {'learning_rate': 0.2776771919889065, 'max_depth': 7, 'subsample': 0.797099936715854, 'colsample_bytree': 0.9599436304173505, 'min_child_weight': 9, 'gamma': 1.6016661813901163e-07, 'reg_alpha': 2.8044972592316943e-06, 'reg_lambda': 0.0008843830097321104, 'max_delta_step': 4}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:35:00,573] Trial 65 finished with value: 0.2264832196232076 and parameters: {'learning_rate': 0.26480109019773124, 'max_depth': 6, 'subsample': 0.8758235103114643, 'colsample_bytree': 0.8600724700978044, 'min_child_weight': 9, 'gamma': 1.545283082206393e-07, 'reg_alpha': 4.925586225654699e-08, 'reg_lambda': 0.0056633716358995825, 'max_delta_step': 5}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:35:02,106] Trial 66 pruned. Trial was pruned at iteration 22.
# [I 2026-09-05 09:35:03,784] Trial 67 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:35:05,595] Trial 68 pruned. Trial was pruned at iteration 19.
# [I 2026-09-05 09:35:09,692] Trial 69 finished with value: 0.22678378623082973 and parameters: {'learning_rate': 0.29787147154046123, 'max_depth': 7, 'subsample': 0.9934451413228584, 'colsample_bytree': 0.8966667201918468, 'min_child_weight': 5, 'gamma': 1.2229634904249601e-06, 'reg_alpha': 2.7816589194739725e-08, 'reg_lambda': 0.0009407099087028421, 'max_delta_step': 4}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:35:10,829] Trial 70 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:35:12,314] Trial 71 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:35:14,394] Trial 72 pruned. Trial was pruned at iteration 19.
# [I 2026-09-05 09:35:18,542] Trial 73 finished with value: 0.22638563487171298 and parameters: {'learning_rate': 0.28083731956908353, 'max_depth': 6, 'subsample': 0.9881056150659685, 'colsample_bytree': 0.8399193981506811, 'min_child_weight': 6, 'gamma': 4.3424266495148354e-08, 'reg_alpha': 1.6563043013897052e-08, 'reg_lambda': 0.0030294127455637605, 'max_delta_step': 3}. Best is trial 2 with value: 0.22599130596819114.
# [I 2026-09-05 09:35:19,576] Trial 74 pruned. Trial was pruned at iteration 7.
# [I 2026-09-05 09:35:20,864] Trial 75 pruned. Trial was pruned at iteration 13.
# [I 2026-09-05 09:35:22,502] Trial 76 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:35:26,117] Trial 77 pruned. Trial was pruned at iteration 34.
# [I 2026-09-05 09:35:27,227] Trial 78 pruned. Trial was pruned at iteration 5.
# [I 2026-09-05 09:35:31,293] Trial 79 finished with value: 0.22634402886811253 and parameters: {'learning_rate': 0.26558869647142724, 'max_depth': 6, 'subsample': 0.9323660930569438, 'colsample_bytree': 0.8663087086056105, 'min_child_weight': 5, 'gamma': 5.938906801515985e-08, 'reg_alpha': 4.482260207400604e-07, 'reg_lambda': 0.0009926214023900587, 'max_delta_step': 9}. Best is trial 2 with value: 0.22599130596819114.

# %% [markdown]
# ## Fetching the optimal parameters

# %%
best_trial = study.best_trial

best_params = best_trial.params.copy()

best_params.update({
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'device': 'cuda',
    'tree_method': 'hist',
    'n_estimators': best_trial.user_attrs['optimal_n_estimators']})

# %% [markdown]
# # Setting up the final model.
#
# Using the best parameters setting up the final pipeline.

# %%
final_model = XGBClassifier(
    **best_params
)

final_pipeline = Pipeline([
    ("preprocess",preprocessor),
    ("model",final_model)
])

# %% [markdown]
# ## Fitting the final model on the Data

# %%
final_pipeline.fit(x, y)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('num', 'passthrough',
#                                                   ['Age', 'Annual_Income_USD',
#                                                    'Daily_Commute_km',
#                                                    'Number_of_Cars_Owned',
#                                                    'Charging_Stations_Near_Home',
#                                                    'Charging_Stations_Near_Work',
#                                                    'Environmental_Concern_Level',
#                                                    'all_charge_stations',
#                                                    'km_by_car']),
#                                                  ('cat', CatBoostEncoder(),
#                                                   ['Gender', 'City_Type',
#                                                    'Current_Car_Type',
#                                                    'Home_...
#                                gamma=1.0808348953714984e-05, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.10104014120285158, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=2, max_depth=5, max_leaves=None,
#                                min_child_weight=6, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=293, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %% [markdown]
# # Predicting the submissions
#
# Using the fitted final model predicting the results.

# %%
x_test = test_df[numerical_columns + categorical_columns]

numeric_predictions = final_pipeline.predict_proba(x_test)[:, 1]
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py:751: UserWarning: [09:35:38] WARNING: /__w/xgboost/xgboost/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)

# %% [markdown]
# ## Saving the results
#
# Saving the results as submission.csv for submitting to the competition.

# %%
results = pd.DataFrame(
    numeric_predictions,
    index=x_test.index,
    columns=[target]
)

print(results[target].value_counts())

results.to_csv("submission.csv")

print(results.info())
# Out:
# Will_Buy_EV
# 0.012710    3
# 0.000272    3
# 0.000407    3
# 0.012324    3
# 0.014074    3
#            ..
# 0.050741    1
# 0.727727    1
# 0.000250    1
# 0.703070    1
# 0.095365    1
# Name: count, Length: 284871, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Index: 286571 entries, 668665 to 955235
# Data columns (total 1 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Will_Buy_EV  286571 non-null  float32
# dtypes: float32(1)
# memory usage: 3.3 MB
# None

# %% [markdown]
# # Feature Importances
#
# Checking the feature importances for feature modifications.

# %%
encoded_cat_names = list(final_pipeline["preprocess"].transformers_[1][1].get_feature_names_out(categorical_columns))
feature_names = numerical_columns + encoded_cat_names

importances = final_pipeline["model"].feature_importances_

print("\n--- Feature Importances ---")
for name, imp in zip(feature_names, importances):
    print(f"{name}: {imp:.4f}")
# Out:
# --- Feature Importances ---
# Age: 0.0047
# Annual_Income_USD: 0.0344
# Daily_Commute_km: 0.0052
# Number_of_Cars_Owned: 0.0027
# Charging_Stations_Near_Home: 0.0037
# Charging_Stations_Near_Work: 0.0030
# Environmental_Concern_Level: 0.5641
# all_charge_stations: 0.0026
# km_by_car: 0.0031
# Gender: 0.0027
# City_Type: 0.0028
# Current_Car_Type: 0.0028
# Home_Charging_Possible: 0.0043
# Subsidy_Available: 0.3108
# Range_Anxiety_Level: 0.0237
# digit_100k: 0.0036
# digit_10k: 0.0044
# digit_1k: 0.0061
# digit_100s: 0.0044
# digit_100: 0.0032
# digit_10: 0.0042
# digit_1: 0.0035

# %% [markdown]
# # This is it
#
# The whole process of xgboost with optuna is given above, i hope you find it useful. Do not forget to upvote, for any questions and problems comment section is always up.
#
# competition: [comptetition](https://www.kaggle.com/competitions/playground-series-s6e9)
# kaggle: [kaggle](https://www.kaggle.com/eymenakb)
# github: [github](https://github.com/EymenAkb)
